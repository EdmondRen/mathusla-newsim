# %% [markdown]
# # How to normalize the exposure
#
# 1. Get the angular distribution of all CRY particles
#    ./cry -n 50000 -o /project/6075887/MATHUSLA/simulation/cosmic/tmp/cosmic_all_50000.txt

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/project/6075887/MATHUSLA/simulation/cosmic/tmp/cosmic_all_50000.txt", delimiter=" ")

# Column names as keys, list of values as dictionary values
data = df.to_dict(orient='list')
data.keys()
# Out:
# dict_keys(['#', 'nEvent', 'nSecondary', 'PDG-id', 'KE[MeV]', 'x[m]', 'y[m]', 'z[m]', 'u', 'v', 'w', 't[s]'])

# %%
data["u"]
# Out:
# [0.0362219,
#  0.0808566,
#  -0.474731,
#  -0.376198,
#  0.518879,
#  0.148074,
#  0.190155,
#  0.698832,
#  0.579213,
#  -0.736436,
#  -0.767369,
#  -0.187972,
#  -0.329563,
#  0.313131,
#  -0.680785,
#  -0.122362,
#  0.102005,
#  0.0407576,
#  -0.0744719,
#  -0.0652268,
#  -0.168777,
#  0.110385,
#  -0.462965,
#  0.505099,
#  0.672667,
#  -0.208564,
#  0.306517,
#  0.154574,
#  -0.158993,
#  -0.0178834,
#  0.676475,
#  -0.618972,
#  0.548715,
#  -0.629401,
#  0.256594,
#  -0.0908317,
#  0.212847,
#  -0.400495,
#  0.408026,
#  0.187908,
#  0.777722,
#  0.406482,
#  0.391547,
#  0.207967,
#  -0.00959135,
#  0.254784,
#  -0.679441,
#  0.0717888,
#  -0.217304,
#  -0.486138,
#  -0.227852,
#  -0.218152,
#  0.339988,
#  -0.529217,
#  0.395239,
#  0.000633,
#  -0.673085,
#  0.203405,
#  0.53156,
#  0.120271,
#  -0.234466,
#  -0.150095,
#  -0.892454,
#  0.916936,
#  0.749007,
#  -0.563649,
#  0.258152,
#  0.722745,
#  0.769576,
#  0.738351,
#  0.369144,
#  0.575008,
#  0.713544,
# ...
